# %%
import pandas as pd

# %%
dfUlta = pd.read_csv ('dfUlta.csv')

# %%
dfSephora = pd.read_csv ('dfSephora.csv')

# %%
dfUlta
# Out:
#      Unnamed: 0              Brands  \
# 0             0          Ace Beauté
# 1             1               ACURE
# 2             2             AG Hair
# 3             3             Ahava\t
# 4             4            Alleyoop
# ..          ...                 ...
# 551         551                YUNI
# 552         552  Yves Saint Laurent
# 553         553           ZitSticka
# 554         554                Zoya
# 555         555      18.21 Man Made
#
#                                                 Owner  Female    POC  \
# 0                                 Niye Aniekan-Attang    True   True
# 1                               Jon and Kristy Guerra    True  False
# 2                                John and Lotte Davis    True  False
# 3                                          Ziva Gilad    True  False
# 4                             Leila Kashani Manshoory    True  False
# ..                                                ...     ...    ...
# ...

# %%
dfSephora
# Out:
#      Unnamed: 0          Brand Name                                 Owner  \
# 0             0      Acqua di Parma                         Laura Burdese
# 1             1        adwoa beauty                           Julian Addo
# 2             2               AERIN                          Aerin Lauder
# 3             3            Algenist  Harrison Dillon and Jonathan Wolfson
# 4             4             Alpha-H                      Michelle Doherty
# ..          ...                 ...                                   ...
# 300         300  Yves Saint Laurent   Yves Saint Laurent and Pierre Bergé
# 301         301           19-69﻿NEW                        Johan Bergelin
# 302         302          54 Thrones                 Christina Funke Tegbe
# 303         303       The 7 Virtues                        Barb Stegemann
# 304         304             8Greens                          Dawn Russell
#
#      Female    POC  Year Founded                             Product Types  \
# ...

# %%
dfUlta.mean()
# Out:
# Unnamed: 0             277.500000
# Female                   0.539568
# POC                      0.194245
# Year Founded          1994.023381
# Number of Products      28.503597
# Clean Brand              0.174460
# dtype: float64

# %%
dfSephora.mean()
# Out:
# Unnamed: 0             152.000000
# Female                   0.632787
# POC                      0.219672
# Year Founded          1998.393443
# Number of Products      27.940984
# Number of Clean          4.518033
# Percent Clean            0.267672
# Clean                    0.318033
# dtype: float64
